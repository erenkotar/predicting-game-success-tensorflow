# %%
from PIL import Image
import os

# %%
path_open = os.getcwd()+"\\icon_webp\\"
path_save = os.getcwd()+"\\icon_png\\"
image_list = os.listdir(path_open)
full_paths = [path_open+x for x in image_list]
only_nums = [x.replace("_icon.webp","") for x in image_list]
image_list
# number = x.tr.replace("_icon","")
# Out:
# ['0_icon.webp',
#  '1000_icon.webp',
#  '1001_icon.webp',
#  '1002_icon.webp',
#  '1003_icon.webp',
#  '1004_icon.webp',
#  '1005_icon.webp',
#  '1006_icon.webp',
#  '1007_icon.webp',
#  '1008_icon.webp',
#  '1009_icon.webp',
#  '100_icon.webp',
#  '1010_icon.webp',
#  '1011_icon.webp',
#  '1012_icon.webp',
#  '1013_icon.webp',
#  '1014_icon.webp',
#  '1015_icon.webp',
#  '1016_icon.webp',
#  '1017_icon.webp',
#  '1018_icon.webp',
#  '1019_icon.webp',
#  '101_icon.webp',
#  '1020_icon.webp',
#  '1021_icon.webp',
#  '1022_icon.webp',
#  '1023_icon.webp',
#  '1024_icon.webp',
#  '1025_icon.webp',
#  '1026_icon.webp',
#  '1027_icon.webp',
#  '1028_icon.webp',
#  '1029_icon.webp',
#  '102_icon.webp',
#  '1030_icon.webp',
#  '1031_icon.webp',
#  '1032_icon.webp',
#  '1033_icon.webp',
#  '1034_icon.webp',
#  '1035_icon.webp',
#  '1036_icon.webp',
#  '1037_icon.webp',
#  '1038_icon.webp',
#  '1039_icon.webp',
#  '103_icon.webp',
#  '1040_icon.webp',
#  '1041_icon.webp',
# ...

# %%
len(image_list) # Instance and number of images matches
# Out:
# 2369

# %%
Image.open(full_paths[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=360x360>

# %%
for num,image_path in zip(only_nums,full_paths):
    image = Image.open(image_path).convert("RGB")
    image.save(path_save+num+".png" , "png")
# Out:
# c:\Users\erenk\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
